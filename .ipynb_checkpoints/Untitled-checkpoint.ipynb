# %%
import pandas as pd

# %% [markdown]
# *First we need to load in our CSV data to do some analysis.*

# %%
pd.read_csv("/Users/nad/Documents/Dropbox/UMD/Teaching/JOUR_479V-779V_Spring_2016/Data/companies.csv")
# Out:
#       nonaccredited_cnt  investment_cnt  accredited_sum  meal_cnt  \
# 0                   NaN             NaN             NaN       NaN
# 1                     1             NaN             NaN      2841
# 2                   NaN             NaN             NaN         1
# 3                   NaN             NaN             NaN      1169
# 4                   NaN             NaN            7900     15845
# 5                   NaN             NaN             NaN     97484
# 6                   NaN             NaN             NaN       NaN
# 7                   NaN             NaN             NaN      1293
# 8                   NaN             NaN             NaN        50
# 9                   NaN             NaN             NaN       699
# 10                  NaN             NaN             NaN      4428
# 11                  NaN             NaN             NaN        80
# 12                  NaN             NaN             NaN        52
# ...
